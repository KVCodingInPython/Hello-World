// %% [markdown]
// # Lab 1
//
// Deadline: **Week 3** (February 13th) in your respective lab session

// %% [markdown]
// ### Name: Kaloyan Velikov
// ### Student ID: 250078219

// %% [markdown]
// ***
//
// ## Question 1 [0.75 marks]

// %% [markdown]
// Write a full Java program (meaning a class that contains a main method) that asks the user for their average percentage across all modules and then prints out their classification: `1st`, `2:1`, `2:2`, `3rd`, `Pass` or `Fail`.
//
// The cutoffs are as follows: [100,...,70] is 1st, [60,...,69] is 2:1, [50,...,59] is 2:2, [45,...,49] is 3rd, [40,...,44] is Pass, and [0,...,39] is Fail.
//
// Example runs:
// `What is your average percentage?` **`67`**
// `Congratulations! You are on a track to graduate with a 2:1!`
//
// `What is your average percentage?` **`38`**
// `Unfortunately, your current classification is a Fail.`

// %% [markdown]
// **Write your answer below:**

// %%
import java.util.Scanner;

// Determines a student's classification based on their average percentage across all modules
class DegreeClassifier {
    public static void main(String[] args) {
        InputPercentage();

    }
    // Handles user integer input.
    public static int ReadInt(String message)
    {
        Scanner scanner = new Scanner(System.in);

        System.out.println(message);

        int answer = Integer.parseInt(scanner.nextLine());

        return answer;
    }
    // Inputs user's average percentage for each module
    public static void InputPercentage ()
    {
        int average_percentage = ReadInt("What is your average percentage?");
        CheckClassification(average_percentage);

        return;
        
    }
    // Checks classification student receives dependent on average percentage
    public static String CheckClassification(int average_percentage)
    {
        String classification;
        
        if (average_percentage >= 70 && average_percentage <= 100)
        {
            classification = "1st";
            PassGrade(classification);
        }
        else if (average_percentage >= 60 && average_percentage <= 69)
        {
            classification = "2:1";
            PassGrade(classification);
        }
        else if (average_percentage >= 50 && average_percentage <= 59)
        {
            classification = "2:2";
            PassGrade(classification);
        }
        else if (average_percentage >= 45 && average_percentage <= 49)
        {
            classification = "3rd";
            PassGrade(classification);
        }
        else if (average_percentage >= 40 && average_percentage <= 44)
        {
            classification = "Pass";
            PassGrade(classification);
        }
        else
        {
            classification = "Fail";
            FailGrade(classification);

        }

        return classification;


    }
    // Prints out a congratulations message if they have not achieved a fail classification
    public static void PassGrade(String classification)
    {
        System.out.println("Congratulations! You are on track to graduate with a " + classification + "!");

        return;
    }
    // Prints if a student has received a fail classification
    public static void FailGrade(String classification)
    {
        System.out.println("Unfortunately, your current classification is a " + classification + ".");

        return;
    }
}

// %% [markdown]
// **Run your program:**

// %%
DegreeClassifier.main(null)
// Out:
// What is your average percentage?
//  67
// Congratulations! You are on track to graduate with a 2:1!

// %% [markdown]
// ***
//
// ## Question 2 [0.75 marks]

// %% [markdown]
// Write a new version of the program from Questions 2 with added input validation. Now the program should ask the user <u>**repeatedly**</u> for their average percentage until a user inputs a number between `0` and `100`.
//
// You may assume that the input is always an integer.
//
// Example run:
// `What is your average percentage?` **`-20`**
// `Invalid input. The number you provided is too low. Please give a number between 0 and 100.`
//
// `What is your average percentage?` **`150`**
// `Invalid input. The number you provided is too high. Please give a number between 0 and 100.`
//
// `What is your average percentage?` **`78`**
// `Congratulations! You are on a track to graduate with a 1st!`

// %% [markdown]
// **Write your answer below:**

// %%
import java.util.Scanner;

// Determines a student's classification based on their average percentage across all modules
class ValidatedDegreeClassifier {
    public static void main(String[] args) {
        InputPercentage();
    }
// Handles user integer input.
    public static int ReadInt(String message)
    {
        Scanner scanner = new Scanner(System.in);

        System.out.println(message);

        int answer = Integer.parseInt(scanner.nextLine());

        return answer;
    }
// Inputs user's average percentage for each module
    public static void InputPercentage ()
    {
        int average_percentage = ReadInt("What is your average percentage?");
        // Validates whether the user has entered a correct percentage value
        while (average_percentage > 100 || average_percentage < 0)
        {
            if (average_percentage < 0)
            {
                average_percentage = ReadInt("Invalid input. The number you provided is too low. Please give a number between 0 and 100.");
            }
            else
            {
                average_percentage = ReadInt("Invalid input. The number you provided is too high. Please give a number between 0 and 100.");
            }
        }
        CheckClassification(average_percentage);

        return;
        
    }
// Checks classification student receives dependent on average percentage
    public static String CheckClassification(int average_percentage)
    {
        String classification;
        
        if (average_percentage >= 70 && average_percentage <= 100)
        {
            classification = "1st";
            PassGrade(classification);
        }
        else if (average_percentage >= 60 && average_percentage <= 69)
        {
            classification = "2:1";
            PassGrade(classification);
        }
        else if (average_percentage >= 50 && average_percentage <= 59)
        {
            classification = "2:2";
            PassGrade(classification);
        }
        else if (average_percentage >= 45 && average_percentage <= 49)
        {
            classification = "3rd";
            PassGrade(classification);
        }
        else if (average_percentage >= 40 && average_percentage <= 44)
        {
            classification = "Pass";
            PassGrade(classification);
        }
        else
        {
            classification = "Fail";
            FailGrade(classification);

        }

        return classification;


    }
 // Prints out a congratulations message if they have not achieved a fail classification
    public static void PassGrade(String classification)
    {
        System.out.println("Congratulations! You are on track to graduate with a " + classification + "!");

        return;
    }
    // Prints if a student has received a fail classification
    public static void FailGrade(String classification)
    {
        System.out.println("Unfortunately, your current classification is a " + classification + ".");

        return;
    }
}

// %% [markdown]
// **Run your program:**

// %%
ValidatedDegreeClassifier.main(null);
// Out:
// What is your average percentage?
//  -20
// Invalid input. The number you provided is too low. Please give a number between 0 and 100.
//  150
// Invalid input. The number you provided is too high. Please give a number between 0 and 100.
//  78
// Congratulations! You are on track to graduate with a 1st!

// %% [markdown]
// ***
// ## Question 3 [0.75 marks]

// %% [markdown]
// Define a class `Student` with two instance variables, `name` and `average`. Add two methods to this class: `printWelcomeMessage` and `determineDegreeClassification`.
//
// `printWelcomeMessage` should print a welcome message that will include the student's name.
// `determineDegreeClassification` should print the degree classifications based on the student's average.
//
// Then define another class called `Main3` that contains the `main` method. The program should ask the user for their name and average. It should then use the inputted information to create an instance of a `Student` and call `printWelcomeMessage` followed by `determineDegreeClassification`.
//
// Example run:
// `What is your name?` **`Bob`**
// `What is your average percentage?` **`67`**
//
// `Welcome Bob to OOP!`
// `Congratulations! You are on a track to graduate with a 2:1!`

// %% [markdown]
// **Write your answer below:**

// %%
class Student {
    String name;
    int average;


    void printWelcomeMessage ()
    {
        System.out.println("Welcome " + name + " to OOP!");

        return;
    }

    void determineDegreeClassification ()
    {
        
        
        if (average >= 70 && average <= 100)
        {
            System.out.println("Congratulations! You are on a track to graduate with a 1st!");
           
           
        }
        else if (average >= 60 && average <= 69)
        {
            System.out.println("Congratulations! You are on a track to graduate with a 2:1!");
           
        }
        else if (average >= 50 && average <= 59)
        {
            System.out.println("Congratulations! You are on a track to graduate with a 2:2!");
           
        }
        else if (average >= 45 && average <= 49)
        {
            System.out.println("Congratulations! You are on a track to graduate with a 3rd!");
          
        }
        else if (average >= 40 && average <= 44)
        {
            System.out.println("Congratulations! You are on a track to graduate with a Pass!");
        
        }
        else
        {
            System.out.println("Unfortunately,  your current classification is a Fail.");
           

        }

        return;
    }

        

}

// %%
import java.util.Scanner;

class Main3 {
    public static void main(String[] args) {
        InputPercentage();

    }

    public static int ReadInt (String message)
    {
        Scanner scanner = new Scanner(System.in);

        System.out.println(message);

        int answer = Integer.parseInt(scanner.nextLine());

        return answer;
    }

    public static String ReadString (String message)
    {
        Scanner scanner = new Scanner(System.in);

        System.out.println(message);

        String answer = scanner.nextLine();

        return answer;
    }

    public static void InputPercentage()
    {
        String name = ReadString("What is your name?");
        int percentage = ReadInt("What is your average percentage?");
        Student s = new Student();
        s.name = name;
        s.average = percentage;
        s.printWelcomeMessage();
        s.determineDegreeClassification();

        return;
    }
        
}

// %% [markdown]
// **Run your program:**

// %%
Main3.main(null);
// Out:
// What is your name?
//  Bob
// What is your average percentage?
//  67
// Welcome Bob to OOP!
// Congratulations! You are on a track to graduate with a 2:1!

// %% [markdown]
// ***

// %% [markdown]
// ## Question 4 [0.75 marks]
//
// Write a method
//
// `int countDuplicates(int[] xs)`
//
// which should return the number of duplicate entries in `xs`.
// For example if `xs = {1,1,1}`, the method should return `3` because `xs[0], xs[1]` constitutes one duplicate pair, `xs[0], xs[2]` the second, and `xs[1],xs[2]` the third. In the example `xs = {0,2,1,0,2,3,0}` the method should return `4` because the duplicate pairs are:
// 1. `xs[0], xs[3]`,
// 2. `xs[0], xs[6]`,
// 3. `xs[3], xs[6]`, and
// 4. `xs[1], xs[4]`.

// %% [markdown]
// **Write your answer below:**

// %%
int countDuplicates(int[] xs) {
    int duplicate_count = 0;
    for (int i = 0; i < xs.length; i++)
        {
            for (int j = i + 1; j < xs.length; j++)
            {
                if (xs[i] == xs[j])
                {
                    duplicate_count = duplicate_count + 1;
                }
            }
        }
    return duplicate_count;
                    
                

}

// %% [markdown]
// **Run your program:**

// %%
countDuplicates(new int[]{1,1,1});
// Out:
// 3

// %% [markdown]
// ***

// %% [markdown]
// ## Question 5 [2 marks] (solution has to be explained)
//
// Write a method
//
// `int[] filterAndReverse(int[] xs, int k)`
//
// which does the following. If `k` is `0` it prints `wrong argument` and immediately returns. Otherwise, it takes only those entries in `xs` that are divisble by the number `k`, reverses them and puts them on a new array which is then returned.
//
// For example when called on the array `{1,2,3,4}` with `k=2`, it should return the array `{4,2}`. This is because we take only the numbers that are divisible by `2`, which in this case is `{2,4}`, and we reverse this array to get `{4,2}`. If we call this method on the array `{1,2,3}` with `k=1`, it should return the array `{3,2,1}`, this is because every number is divisible by `1`.
//
// *Hint:* First go through the array `xs` to see how many entries are divisble by `k`, this number will be the length of the array which you should return.

// %% [markdown]
// **Write your answer below:**

// %%
int[] filterAndReverse(int[] xs, int k) {
    int count = 0; 

    if (k == 0)
    {
        System.out.println("wrong argument.");
    }
  
        
        for (int i = 0; i < xs.length; i++)
        {
            if (xs[i] % k == 0)
            {
                count = count + 1;
                
            }
        
            
        }
        int SortedArr [] = new int[count];
        int n = SortedArr.length;
        int z = n - 1;
        int idx = 0;
        for (int j = 0; j < xs.length; j++)
        {
            if (xs[j] % k == 0)
            {
                SortedArr[idx++] = xs[j];
                
            }
        }
        System.out.println(Arrays.toString(SortedArr));
        


        for (int x = 0; x < z; x++)
        {
            int temp = SortedArr[x];
            SortedArr[x] = SortedArr[z];
            SortedArr[z] = temp;

            z = z - 1;
        }

    

    return SortedArr;
        
        
            

}

// %% [markdown]
// **Run your program:**

// %%
System.out.println(Arrays.toString(filterAndReverse(new int[]{2,3,4},2)));
// Out:
// [2, 4]
// [4, 2]
